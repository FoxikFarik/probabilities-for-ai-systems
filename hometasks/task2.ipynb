# %%
import scipy.special as sc

# %% [markdown]
# # Задача 1.38
# Пятитомное собрание сочинений расположено на полке в случайном порядке. Какова вероятность того, что книги стоят слева направо в порядке нумерации томов (от 1 до 5)?

# %%
1 / sc.perm(5, 5)
# Out:
# np.float64(0.008333333333333333)

# %% [markdown]
# # Задача 1.43
# Наудачу взятый телефонный номер состоит из 5 цифр. Какова вероятность того, что в нем все цифры: а) различные; б) одинаковые; в) нечетные? Известно, что номер телефона не на-
# чинается с цифры ноль.

# %%
#а
9 * 9 * 8 * 7 * 6 / (9 * 10 ** 4)
# Out:
# 0.3024

# %%
#б
9 / (9 * 10 ** 4)
# Out:
# 0.0001

# %%
#в
5 ** 5 / (9 * 10 ** 4)
# Out:
# 0.034722222222222224

# %% [markdown]
# # Задача 1.48
# В старинной игре в кости необходимо было для выигрыша получить при бросании трех игральных костей сумму очков, превосходящую 10. Найти вероятности: а) выпадения ll очков; б) выигрыша.

# %%
from itertools import product
#а
throws = list(product(range(1, 7), repeat=3))
count = 0
for throw in throws:
    if sum(throw) == 11:
        count += 1
print(count/6**3)
# Out:
# 0.125

# %%
#б
throws = list(product(range(1, 7), repeat=3))
count = 0
for throw in throws:
    if sum(throw) > 10:
        count += 1
print(count/6**3)
# Out:
# 0.5
